# %% [markdown]
# # 1. 자료 불러오기(Open API)

# %%
import requests
import pandas as pd

# %%
apikey = '427a56776a6b6173363741644b7756'

# %% [markdown]
# #### 요청할 API 주소 만들기

# %% [markdown]
# - 한 번에 1000개 밖에 출력 되지 않기 때문에 나눠서 출력

# %%
startnum = 1
endnum = 1000
url = f'http://openapi.seoul.go.kr:8088/{apikey}/json/bikeList/{startnum}/{endnum}/'

# %%
json = requests.get(url).json()

# %%
json
# Out:
# {'rentBikeStatus': {'list_total_count': 1000,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다.'},
#   'row': [{'rackTotCnt': '7',
#     'stationName': '101. (구)합정동 주민센터',
#     'parkingBikeTotCnt': '7',
#     'shared': '100',
#     'stationLatitude': '37.54956055',
#     'stationLongitude': '126.90575409',
#     'stationId': 'ST-3'},
#    {'rackTotCnt': '22',
#     'stationName': '102. 망원역 1번출구 앞',
#     'parkingBikeTotCnt': '27',
#     'shared': '123',
#     'stationLatitude': '37.55564880',
#     'stationLongitude': '126.91062927',
#     'stationId': 'ST-4'},
#    {'rackTotCnt': '16',
#     'stationName': '103. 망원역 2번출구 앞',
#     'parkingBikeTotCnt': '9',
#     'shared': '56',
#     'stationLatitude': '37.55495071',
#     'stationLongitude': '126.91083527',
#     'stationId': 'ST-5'},
#    {'rackTotCnt': '15',
#     'stationName': '104. 합정역 1번출구 앞',
#     'parkingBikeTotCnt': '11',
#     'shared': '73',
#     'stationLatitude': '37.55062866',
# ...

# %%
json.keys()
# Out:
# dict_keys(['rentBikeStatus'])

# %%
json['rentBikeStatus'].keys()
# Out:
# dict_keys(['list_total_count', 'RESULT', 'row'])

# %%
json['rentBikeStatus']['list_total_count']
# Out:
# 1000

# %%
json['rentBikeStatus']['RESULT']
# Out:
# {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다.'}

# %%
json['rentBikeStatus']['row']
# Out:
# [{'rackTotCnt': '7',
#   'stationName': '101. (구)합정동 주민센터',
#   'parkingBikeTotCnt': '7',
#   'shared': '100',
#   'stationLatitude': '37.54956055',
#   'stationLongitude': '126.90575409',
#   'stationId': 'ST-3'},
#  {'rackTotCnt': '22',
#   'stationName': '102. 망원역 1번출구 앞',
#   'parkingBikeTotCnt': '27',
#   'shared': '123',
#   'stationLatitude': '37.55564880',
#   'stationLongitude': '126.91062927',
#   'stationId': 'ST-4'},
#  {'rackTotCnt': '16',
#   'stationName': '103. 망원역 2번출구 앞',
#   'parkingBikeTotCnt': '9',
#   'shared': '56',
#   'stationLatitude': '37.55495071',
#   'stationLongitude': '126.91083527',
#   'stationId': 'ST-5'},
#  {'rackTotCnt': '15',
#   'stationName': '104. 합정역 1번출구 앞',
#   'parkingBikeTotCnt': '11',
#   'shared': '73',
#   'stationLatitude': '37.55062866',
#   'stationLongitude': '126.91498566',
#   'stationId': 'ST-6'},
#  {'rackTotCnt': '7',
#   'stationName': '105. 합정역 5번출구 앞',
#   'parkingBikeTotCnt': '9',
#   'shared': '129',
# ...

# %% [markdown]
# #### 데이터 프레임 형식으로 만들기

# %%
data = pd.DataFrame(json['rentBikeStatus']['row'])

# %%
data
# Out:
#     rackTotCnt                 stationName parkingBikeTotCnt shared  \
# 0            7            101. (구)합정동 주민센터                 7    100
# 1           22             102. 망원역 1번출구 앞                27    123
# 2           16             103. 망원역 2번출구 앞                 9     56
# 3           15             104. 합정역 1번출구 앞                11     73
# 4            7             105. 합정역 5번출구 앞                 9    129
# ..         ...                         ...               ...    ...
# 995         22                  1355. 보문2교                 7     32
# 996         22               1357. 북한산보국문역                 9     41
# 997          9               1358. 정릉도서관 앞                 2     22
# 998         22  1359. 장위뉴타운 꿈에 숲 코오롱 하늘채 앞                 4     18
# 999         12                   1360. 정릉역                 6     50
#
#     stationLatitude stationLongitude stationId
# 0       37.54956055     126.90575409      ST-3
# 1       37.55564880     126.91062927      ST-4
# ...

# %% [markdown]
# #### 1001~2000번 째 데이터 추가하기

# %%
startnum = 1001
endnum = 2000
url1 = f'http://openapi.seoul.go.kr:8088/{apikey}/json/bikeList/{startnum}/{endnum}/'

json1 = requests.get(url1).json()

# %%
json.keys()
# Out:
# dict_keys(['rentBikeStatus'])

# %%
json1['rentBikeStatus']
# Out:
# {'list_total_count': 1000,
#  'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다.'},
#  'row': [{'rackTotCnt': '22',
#    'stationName': '1361. 홍익중고 입구',
#    'parkingBikeTotCnt': '2',
#    'shared': '9',
#    'stationLatitude': '37.59284210',
#    'stationLongitude': '127.00212097',
#    'stationId': 'ST-1424'},
#   {'rackTotCnt': '12',
#    'stationName': '1362. 보문역6번출구 앞',
#    'parkingBikeTotCnt': '14',
#    'shared': '117',
#    'stationLatitude': '37.58509827',
#    'stationLongitude': '127.01967621',
#    'stationId': 'ST-1454'},
#   {'rackTotCnt': '17',
#    'stationName': '1363. 보문4교 인근',
#    'parkingBikeTotCnt': '7',
#    'shared': '41',
#    'stationLatitude': '37.58375168',
#    'stationLongitude': '127.02194977',
#    'stationId': 'ST-1455'},
#   {'rackTotCnt': '12',
#    'stationName': '1364. 성북동 치안센터 앞',
#    'parkingBikeTotCnt': '2',
#    'shared': '17',
#    'stationLatitude': '37.59017181',
#    'stationLongitude': '127.00408936',
#    'stationId': 'ST-1456'},
# ...

# %%
data1 = pd.DataFrame(json1['rentBikeStatus']['row'])

# %%
data1
# Out:
#     rackTotCnt       stationName parkingBikeTotCnt shared stationLatitude  \
# 0           22     1361. 홍익중고 입구                 2      9     37.59284210
# 1           12   1362. 보문역6번출구 앞                14    117     37.58509827
# 2           17     1363. 보문4교 인근                 7     41     37.58375168
# 3           12  1364. 성북동 치안센터 앞                 2     17     37.59017181
# 4           17      1365. 선잠단지 앞                 2     12     37.59336090
# ..         ...               ...               ...    ...             ...
# 995         12  3516. 구의아리수정수센터앞                 0      0     37.54370499
# 996         12       3517. 용마사거리                 7     58     37.56252670
# 997         10   3518. 군자역 7번출구뒤                 6     60     37.55686188
# 998         12       3520. 광진경찰서                 2     17     37.54251862
# 999         12    3521. 현대홈타운 뒷길                10     83     37.54342651
#
#     stationLongitude stationId
# 0       127.00212097   ST-1424
# ...

# %% [markdown]
# #### 2001~3000번 째 데이터 추가하기

# %%
startnum = 2001
endnum = 3000

url2 = f'http://openapi.seoul.go.kr:8088/{apikey}/json/bikeList/{startnum}/{endnum}/'
json2 = requests.get(url2).json()

# %%
data2 = pd.DataFrame(json2['rentBikeStatus']['row'])

# %% [markdown]
# #### 데이터 병합

# %%
data = pd.concat([data, data1, data2])

# %% [markdown]
# #### 인덱스 다시 정리하기

# %%
data = data.reset_index().drop('index', axis=1)

# %%
data.head()
# Out:
#   rackTotCnt       stationName parkingBikeTotCnt shared stationLatitude  \
# 0          7  101. (구)합정동 주민센터                 7    100     37.54956055
# 1         22   102. 망원역 1번출구 앞                27    123     37.55564880
# 2         16   103. 망원역 2번출구 앞                 9     56     37.55495071
# 3         15   104. 합정역 1번출구 앞                11     73     37.55062866
# 4          7   105. 합정역 5번출구 앞                 9    129     37.55000687
#
#   stationLongitude stationId
# 0     126.90575409      ST-3
# 1     126.91062927      ST-4
# 2     126.91083527      ST-5
# 3     126.91498566      ST-6
# 4     126.91482544      ST-7

# %%
len(data)
# Out:
# 2123

# %%
data.iloc[1,4]
# Out:
# '37.55564880'

# %% [markdown]
# # 2. 지도 시각화

# %%
import folium

# %% [markdown]
# #### 서울역을 중심으로 지도 만들기

# %%
m = folium.Map(location = ['37.5536067','126.9674308'], zoom_start = 13)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 미니맵 만들기

# %%
from folium.plugins import MiniMap
from folium.plugins import MarkerCluster

# %%
minimap = MiniMap()

# %%
m.add_child(minimap)

# %% [markdown]
# #### 마커 추가하기

# %%
# 지도 생성하기
m = folium.Map(location = ['37.5536067','126.9674308'], zoom_start = 13)

# 미니맵 추가하기
minimap = MiniMap()
m.add_child(minimap)


# 마커 클러스터 만들기    
marker_cluster = MarkerCluster().add_to(m)

# 마커 추가하기

for i in range(len(data)):
    lat = data.loc[i, 'stationLatitude']
    long = data.loc[i, 'stationLongitude']
    name = data.loc[i, 'stationName']
    available = int(data.loc[i, 'parkingBikeTotCnt'])
    total = int(data.loc[i, 'rackTotCnt'])

    
# 색상 추가하기

    if available/total > 0.5:
        color = 'blue'
    elif available < 2:
        color = 'red'
    else:
        color = 'green'
    icon = folium.Icon(color = color, icon = 'info-sign')
    folium.Marker(location = [lat, long],
                  tooltip = f'{name} : {available}',
                  icon=icon
                 ).add_to(marker_cluster)
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 저장하기

# %%
m.save('./Bicycle_clustermap.html')
